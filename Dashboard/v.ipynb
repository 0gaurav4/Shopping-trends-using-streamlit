# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gaura\Downloads\python practice\Project\Dashboard\shopping_trends.csv")
df.sample(5)
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 2861         2862   66  Female           Coat  Outerwear
# 2221         2222   25    Male         Shorts   Clothing
# 2640         2641   30    Male          Skirt   Clothing
# 1916         1917   26    Male         Hoodie   Clothing
# 1163         1164   26    Male          Pants   Clothing
#
#       Purchase Amount (USD)     Location Size  Color  Season  Review Rating  \
# 2861                     54     Maryland    M   Teal    Fall            3.4
# 2221                     88       Kansas   XL  White    Fall            3.0
# 2640                     75      Indiana    L  Olive  Summer            4.0
# 1916                     50  Connecticut    S  Beige  Winter            3.0
# 1163                     56    Tennessee    L  White  Summer            3.0
#
#      Subscription Status Payment Method   Shipping Type Discount Applied  \
# 2861                  No     Debit Card   Free Shipping               No
# ...

# %%
# 1. What is the average age of the customers in the dataset?

df["Age"].mean()
# Out:
# 44.06846153846154

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (20, 6))
ax = df["Gender"].value_counts().plot(kind = 'bar', rot = 0)
ax.set_xticklabels(('Male', 'Female'))
fig.show()
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_4292\3531564281.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#connect graph to html
import plotly.express as px

fig = px.bar(df, x="Category", y="Purchase Amount (USD)", color="Category")
fig.show()

# %%
#graph for gender and age

fig = px.bar(df.head(10), x="Age", y="Purchase Amount (USD)", color="Gender")
fig.show()
